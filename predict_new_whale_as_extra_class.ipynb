# %%
% matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas
import torch, torch.utils.data, torchvision
import PIL
import os.path
import time
# import skimage, skimage.io
import time
import copy
from my_utils import *

# %%
full_model = torch.load('full_model_new_whale_as_extra_class_gpu.pt')

# %%
# define the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
full_model.to(device);

# %%
df_test_no_leakage = pandas.read_csv('data/test_no_leakage.csv')

# %%
MEAN = [0.485, 0.456, 0.406] # expected by pretrained resnet18
STD = [0.229, 0.224, 0.225] # expected by pretrained resnet18

# define transformations without data augmentation
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224,224)),
    torchvision.transforms.ToTensor(), # Expected by pretrained neural network
    torchvision.transforms.Normalize(MEAN, STD) # Expected by pretrained neural network
    ])

# %%
test_data = TestDataset(df_test_no_leakage.reindex(columns=['Image']),'./data/test/',transform=transforms)
test_dataloader = torch.utils.data.DataLoader(test_data,\
                                              batch_size=256,\
                                              shuffle=False,\
                                              num_workers=4,\
                                              sampler=None)

# %%
df_train = pandas.read_csv('data/train_no_duplicates.csv')
categories = WhaleDataset(df_train.reindex(columns=['Image','Id']),'./data/').categories

# %%
threshhold = 0.2
new_whale_index = categories.index('new_whale')

prob = []
Id = []
image_name = []
for image, im_name in test_dataloader:
    image = image.to(device)
    
    out = torch.exp(full_model(image))
    norm = torch.norm(out,p=1,dim=1,keepdim=True)
    out = out/norm
    
    prob_tmp, Id_tmp = torch.topk(out,k=5,dim=1)
    prob_tmp = prob_tmp.tolist()
    Id_tmp = Id_tmp.tolist()
    
    # Note image is a tuple. The final batch may have a
    # different length. That is why I am using the length of image_names
    # in xrange below.
    for j in xrange(len(image)):
        
        i = 0
        for p in prob_tmp[j]:
            if p < threshhold:
                Id_tmp[j].insert(i,0)
                Id_tmp[j].pop(5)
                break
            i+=1
            
        Id.append([categories[i] for i in Id_tmp[j]])
        prob.append(prob_tmp[j])
        image_name.append(im_name[j])

# %%
df_prediction = pandas.DataFrame({'Image' : image_name, 'Id' : Id})
df_prediction.Id = df_prediction.Id.apply(lambda x: ' '.join(x))
df_prediction.reindex(columns=['Image','Id'])
# Out:
#               Image                                                 Id
# 0      bf2de0b3.jpg  new_whale w_7311fe4 w_69a9f72 w_d19a884 w_fe5e78b
# 1      97545d3c.jpg  new_whale w_8fab53d w_7c943ab w_ace8c54 w_b7d5069
# 2      9c814a76.jpg  new_whale w_b7d5069 w_759b647 w_3197568 w_307065e
# 3      bead0b7e.jpg  new_whale w_7554f44 w_ff7630a w_47d2bc6 w_434ad6a
# 4      1f35985e.jpg  new_whale w_66c1b54 w_861cc1c w_21e178f w_d9adb4f
# 5      0b8448c8.jpg  new_whale w_143b201 w_ee948c6 w_99c07e8 w_e64c9a6
# 6      696cdb1f.jpg  new_whale w_43be268 w_434ad6a w_71764b4 w_7285eb3
# 7      9c165fe1.jpg  new_whale w_73d5489 w_edf5f77 w_3aa2073 w_5a81425
# 8      d56d47b4.jpg  new_whale w_43be268 w_3af4e73 w_53064a6 w_e61dd6d
# 9      395b47a3.jpg  new_whale w_ee948c6 w_29f00ae w_2111212 w_73d5489
# 10     a8e0ffb7.jpg  new_whale w_8b56cb1 w_2832e90 w_147b62b w_48a98d7
# 11     d9335bf5.jpg  new_whale w_73d5489 w_b0aed4a w_02c9470 w_0e4f53c
# 12     96b536d2.jpg  new_whale w_ee948c6 w_83034c7 w_2f54c3c w_f3db3f1
# 13     e085197e.jpg  new_whale w_43be268 w_c3d523d w_d663f4f w_b41e229
# 14     572a97a3.jpg  new_whale w_4fd48e7 w_aa16da4 w_d19a884 w_47f29cd
# 15     199354b8.jpg  new_whale w_4e52a49 w_e826a6f w_dbda0d6 w_9a5cd8e
# 16     372d4390.jpg  new_whale w_02c9470 w_56f2b1e w_8fd5636 w_2e872af
# 17     d4288df7.jpg  new_whale w_5a6d315 w_7028d77 w_8a438a4 w_fea7fe6
# 18     b1cbc41c.jpg  new_whale w_099ab25 w_721d2e9 w_aa16da4 w_c0d494d
# 19     ad46f5c5.jpg  new_whale w_20c671c w_b9e00eb w_15f29b7 w_293b5e4
# 20     76da3d3a.jpg  new_whale w_b7d5069 w_b39c722 w_bbf20b4 w_8fab53d
# 21     306edad0.jpg  new_whale w_f19faeb w_73d5489 w_eb0a6ed w_b0362e2
# 22     d333cd4b.jpg  new_whale w_18df014 w_7311fe4 w_7b770ec w_8e23e4c
# 23     8458b1a7.jpg  new_whale w_da63cba w_3197568 w_c0d494d w_73b705e
# 24     7b7414a4.jpg  new_whale w_b9e00eb w_1da7080 w_1eafe46 w_29f00ae
# 25     ed05a299.jpg  new_whale w_b678944 w_86113c4 w_b39c722 w_9ca943b
# 26     944f319b.jpg  new_whale w_73d5489 w_1dd8e68 w_e449d3a w_0e4f53c
# 27     307dc2bd.jpg  new_whale w_43be268 w_ee9c4d7 w_0beef28 w_d88328d
# 28     3c8062ab.jpg  new_whale w_8867074 w_434ad6a w_8e451d9 w_a913945
# 29     12bef608.jpg  w_1eafe46 new_whale w_d36f58c w_a837660 w_8867074
# ...             ...                                                ...
# 13689  d0d8b37a.jpg  new_whale w_59eb8ae w_18eee6e w_fc7cc24 w_8d83172
# 13690  6ccba84d.jpg  new_whale w_b678944 w_847088b w_851a7f4 w_7311fe4
# 13691  cc54dbed.jpg  new_whale w_c3d523d w_7c7a78c w_c30959a w_8fab53d
# 13692  f31d85ea.jpg  new_whale w_987a36f w_e61dd6d w_77e1ae3 w_2168ae2
# 13693  6d4c50cc.jpg  new_whale w_2c46a73 w_aa16da4 w_ee17a08 w_2fe43c7
# 13694  9c277704.jpg  new_whale w_91572bb w_9b401eb w_71e6583 w_27736a0
# 13695  26a8ea64.jpg  new_whale w_b0e05b1 w_5966fff w_6232813 w_a048f26
# 13696  69e263b4.jpg  new_whale w_4fd48e7 w_fea7fe6 w_2dae424 w_d37b55b
# 13697  519c882c.jpg  new_whale w_288e40b w_2111212 w_9205d40 w_29cf24b
# 13698  2e9b1bb8.jpg  new_whale w_4e52a49 w_48a98d7 w_0acce53 w_1e1a051
# 13699  ac8dccd0.jpg  new_whale w_d88328d w_715d152 w_ee17a08 w_2d99a0c
# 13700  fd203751.jpg  new_whale w_7e8b270 w_824f286 w_b0e05b1 w_2071a4c
# 13701  d9e4447d.jpg  new_whale w_8867074 w_74e15fc w_6d4dedc w_ff1b64c
# 13702  c9ff9bb5.jpg  new_whale w_e826a6f w_b7d5069 w_434ad6a w_0a97a25
# 13703  aeb120dd.jpg  new_whale w_2a18a44 w_1a5e7a2 w_86b9dfd w_d663f4f
# 13704  bb273246.jpg  new_whale w_1dff010 w_0a97a25 w_dbda0d6 w_569c2c7
# 13705  ce4b73b3.jpg  new_whale w_94cd45e w_2b930da w_66c1b54 w_cb7b682
# 13706  315b79a4.jpg  new_whale w_56f2b1e w_e548eb7 w_d1917df w_962164f
# 13707  bc710675.jpg  new_whale w_aa16da4 w_4c9d3df w_bbf20b4 w_861cc1c
# 13708  7780cd6f.jpg  new_whale w_73d5489 w_e449d3a w_a524549 w_f115d53
# 13709  a66bee0e.jpg  new_whale w_66c1b54 w_d36f58c w_2c1dafa w_7763134
# 13710  5e19553b.jpg  new_whale w_6c23fcc w_2d99a0c w_a18d0dc w_1969a9d
# 13711  da3a722c.jpg  new_whale w_8867074 w_8e451d9 w_1287fbc w_da2efe0
# 13712  627210df.jpg  new_whale w_f3db3f1 w_b9e00eb w_8b15b96 w_8459e39
# 13713  87953a25.jpg  new_whale w_43be268 w_4e52a49 w_48a98d7 w_89317b0
# 13714  d0c9c8d3.jpg  new_whale w_d9adb4f w_987a36f w_4659acf w_656afeb
# 13715  85454888.jpg  new_whale w_cd65880 w_f19faeb w_bd61ca9 w_6232813
# 13716  9b3091f2.jpg  new_whale w_b96d4e0 w_dbda0d6 w_b7d5069 w_fa32440
# 13717  53cd0f31.jpg  new_whale w_73d5489 w_02c9470 w_0899118 w_af890ad
# 13718  db8a291b.jpg  new_whale w_3af4e73 w_2c3f440 w_94e1ed4 w_1dff010
#
# [13719 rows x 2 columns]

# %%
# Load the prediction obtained with phash
phash_pred = pandas.read_csv('my_submission_phash_only.csv')

# %%
# Choose only those images which are not contained in the prediction made with the CNN
phash_pred = phash_pred[phash_pred.Image.apply(lambda x: x not in df_prediction.Image.values)]

# %%
df_combined = df_prediction.append(phash_pred,ignore_index=True)

# %%
df_combined = df_combined.reindex(columns=['Image','Id'])
df_combined.to_csv('my_submission_new_whale_as_extra_class_threshhold_{:.2f}.csv'.\
                   format(threshhold),index=False)
