# %%
% matplotlib notebook
from my_utils import *
import numpy as np
import pandas
import torch, torchvision
import os

# %%
full_model = torch.load('./full_model_gpu.pt',map_location= lambda storage, loc: storage)

# define the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
full_model.to(device);

# %%
filenames = os.listdir('./data/test/')
filenames = filenames[:64]

# %%
MEAN = [0.485, 0.456, 0.406] # expected by pretrained resnet18
STD = [0.229, 0.224, 0.225] # expected by pretrained resnet18

# define transformations without data augmentation
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224,224)),
    torchvision.transforms.ToTensor(), # Expected by pretrained neural network
    torchvision.transforms.Normalize(MEAN, STD) # Expected by pretrained neural network
    ])

# %%
test_df = pandas.DataFrame({'Id':filenames})

# %%
test_data = TestDataset(test_df,'./data/test/',transform=transforms)

# %%
# load the trainind data to get a list of the categories
train_df = pandas.read_csv('./data/train.csv')
train_data = WhaleDataset(train_df,'./data/',transform=None)
categories = train_data.categories

# %%
test_dataloader = torch.utils.data.DataLoader(test_data,\
                                               batch_size=4,\
                                               num_workers=4,\
                                               shuffle=False,\
                                               sampler=None)

# %%
df_Id, df_prob = predict_v2(full_model,test_dataloader,device,categories)
# Out:
# Elapsed time: 7.7623

# %%
df_prob
# Out:
#            Image                                        Probability
# 0   bf2de0b3.jpg  [0.872779130936, 0.0516964197159, 0.0290544275...
# 1   97545d3c.jpg  [0.680279076099, 0.0758891254663, 0.0557172931...
# 2   aff1076a.jpg  [0.791519761086, 0.165625736117, 0.02021553739...
# 3   9c814a76.jpg  [0.995662510395, 0.000881057290826, 0.00067773...
# 4   bead0b7e.jpg  [0.682475805283, 0.092581063509, 0.08885043859...
# 5   1f35985e.jpg  [0.648008227348, 0.249395221472, 0.03098106011...
# 6   270d9835.jpg  [0.540248632431, 0.457743257284, 0.00068186246...
# 7   0b8448c8.jpg  [0.983567178249, 0.00394120626152, 0.003405109...
# 8   696cdb1f.jpg  [0.963841795921, 0.0283355060965, 0.0028683182...
# 9   9c165fe1.jpg  [0.886606276035, 0.0507569946349, 0.0206374824...
# 10  d56d47b4.jpg  [0.980983138084, 0.00603567017242, 0.003345256...
# 11  395b47a3.jpg  [0.935382544994, 0.0154279554263, 0.0087901139...
# 12  a8e0ffb7.jpg  [0.870045363903, 0.0510535389185, 0.0495920106...
# 13  d9335bf5.jpg  [0.952319085598, 0.011196507141, 0.00696194125...
# 14  96b536d2.jpg  [0.977545499802, 0.0108036855236, 0.0036518422...
# 15  e085197e.jpg  [0.997043192387, 0.0011827320559, 0.0005913660...
# 16  572a97a3.jpg  [0.88918364048, 0.0218437183648, 0.01657477393...
# 17  199354b8.jpg  [0.935669898987, 0.0325782299042, 0.0094483215...
# 18  372d4390.jpg  [0.993534743786, 0.00579177960753, 0.000174864...
# 19  d4288df7.jpg  [0.377770185471, 0.241475641727, 0.14652496576...
# 20  9bc04aee.jpg  [0.954890370369, 0.0273447185755, 0.0061665847...
# 21  0a1e0918.jpg  [0.985322117805, 0.0105441305786, 0.0011573603...
# 22  b1cbc41c.jpg  [0.955720841885, 0.0203579347581, 0.0053631542...
